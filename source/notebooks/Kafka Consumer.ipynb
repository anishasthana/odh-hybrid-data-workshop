# %%
! pip install kafka-python

# %%
import json

# %%
from kafka import KafkaConsumer


consumer = KafkaConsumer("test",group_id="test-group",auto_offset_reset='earliest',bootstrap_servers='odh-message-bus-kafka-bootstrap.<OCP_PROJECT_NAME>.svc.cluster.local:9092')

try:
    for record in consumer:
        msg = record.value.decode('utf-8')
        print(msg)
except KeyboardInterrupt:
    pass
finally:
    # Don't forget to clean up after yourself!
    print("Closing KafkaConsumer...")
    consumer.close()

print("done")
