# %% [markdown]
# # Shared Data Context

# %% [markdown]
# The intent of this notebook is to provide examples of how data scientists can use object storage, and more specifically, Ceph object storage, much in the same way they are accoustomed to interacting with Amazon Simple Storage Service (S3). This is made possible because Ceph's object storage gateway offers excellent fidelity with the modalities of Amazon S3.

# %% [markdown]
# # Working with Boto

# %% [markdown]
# Boto is an integrated interface to current and future infrastructural services offered by Amazon Web Services. Amoung the services it provides interfaces for is Amazon S3. For lightweight analysis of data using python tools like numpy or pandas, it is handy to interact with data stored in object storage using pure python. This is where Boto shines. The base-notebook from [radanalyticsio](https://radanalytics.io) doesn't include Boto, but you can install it from the comfort of a notebook using the conda install command below. If you find yourself using Boto frequently, it might be worth modifying [base-notebook](https://github.com/radanalyticsio/base-notebook) and building a custom notebook image that includes Boto.

# %%
import sys

# %%
import os
import boto3


s3_endpoint_url = os.environ['S3_ENDPOINT_URL']
s3_access_key = os.environ['AWS_ACCESS_KEY_ID']
s3_secret_key = os.environ['AWS_SECRET_ACCESS_KEY']
s3_bucket_name = os.environ['JUPYTERHUB_USER']

s3 = boto3.client('s3','us-east-1', endpoint_url= s3_endpoint_url,
                       aws_access_key_id = s3_access_key,
                       aws_secret_access_key = s3_secret_key)

# %% [markdown]
# Creating a bucket, uploading and object (put), and listing the bucket.

# %%
s3.create_bucket(Bucket=s3_bucket_name)
s3.put_object(Bucket=s3_bucket_name,Key='object',Body='data')
for key in s3.list_objects(Bucket=s3_bucket_name)['Contents']:
    print(key['Key'])
# Out:
# kube-metrics/_SUCCESS
# kube-metrics/part-00000-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00001-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00002-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00003-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00004-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00005-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00006-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00007-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00008-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00009-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00010-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00011-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00012-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00013-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00014-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00015-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00016-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00017-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00018-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00019-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00020-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00021-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00022-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00023-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00024-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00025-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00026-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00027-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00028-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00029-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00030-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00031-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00032-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00033-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00034-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00035-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00036-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00037-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00038-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00039-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00040-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00041-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00042-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00043-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00044-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00045-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00046-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00047-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00048-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00049-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00050-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00051-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00052-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00053-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00054-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00055-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00056-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00057-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00058-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00059-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00060-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00061-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00062-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00063-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00064-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00065-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00066-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00067-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00068-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00069-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00070-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00071-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00072-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00073-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00074-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# kube-metrics/part-00075-60b830bd-ab59-4bb3-b59a-3102450831f5-c000.json.bz2
# models/trip_report_feature_dimension.pickle
# models/trip_report_model
# models/trip_report_tokenizer.pickle
# object
# trip_report.tsv/_SUCCESS
# trip_report.tsv/part-00000-d790e032-51f1-4898-b34a-811805674071-c000.csv

# %% [markdown]
# # Working with Spark

# %% [markdown]
# When running an application you can either establish a Spark session locally in the notebook pod, or point it to a remote Spark cluster. Oshinko is a collection of components from the radanalyticsio community that aid in the provisioning and scaling of Spark clusters for intelligent applications.

# %%
import os
import pyspark

from pyspark.context import SparkContext
from pyspark.sql import SparkSession, SQLContext

##################################################
# This is a HACK until we can resolve the issue
# preventing the spark nodes from resolving pod
# names
spark_driver_host = "10.131.4.15"
##################################################

os.environ["PYSPARK_SUBMIT_ARGS"] = f"--conf spark.driver.host={spark_driver_host} --conf spark.cores.max=6 --conf spark.executor.instances=2 --conf spark.executor.memory=3G --conf spark.executor.cores=3 --conf spark.driver.memory=4G --packages com.amazonaws:aws-java-sdk:1.8.0,org.apache.hadoop:hadoop-aws:2.8.5 pyspark-shell"
spark_cluster_url = f"spark://{os.environ['SPARK_CLUSTER']}:7077"
spark = SparkSession.builder.master(spark_cluster_url).getOrCreate()

# %%
hadoopConf=spark.sparkContext._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3a.endpoint", s3_endpoint_url)
hadoopConf.set("fs.s3a.access.key", s3_access_key)
hadoopConf.set("fs.s3a.secret.key", s3_secret_key)
hadoopConf.set("fs.s3a.path.style.access", "true")
hadoopConf.set("fs.s3a.connection.ssl.enabled", "false")

# %%
import socket
spark.range(100, numPartitions=100).rdd.map(lambda x: socket.gethostname()).distinct().collect()
# Out:
# ['jupyterhub-nb-user99']

# %%
df0 = spark.read.text(f"s3a://{s3_bucket_name}/object")

# %%
df0
# Out:
# DataFrame[value: string]

# %% [markdown]
# # Working with a Hybrid Data Context

# %% [markdown]
# As of Hadoop 2.8, S3A supports per bucket configuration. This is very powerful. It allows us to have a distinct S3A configuration, with a different endpoint and different set of credentials. With this I can use a single Spark context to read a parquet file from a bucket in the public cloud (Amazon S3) into a data frame, then turn around and write that dataframe as a parquet file into a bucket that exists in the Ceph Nano service running in Minishift.

# %%
hadoopConf=spark.sparkContext._jsc.hadoopConfiguration()
hadoopConf.set("fs.s3a.bucket.bd-dist.endpoint", "s3.amazonaws.com")
hadoopConf.set("fs.s3a.bucket.bd-dist.aws.credentials.provider", "org.apache.hadoop.fs.s3a.AnonymousAWSCredentialsProvider")

# %% [markdown]
# __Public to Private ETL__

# %% [markdown]
# Simply read tab separated data from a bucket in Amazon S3 and write it back out to a bucket in our Ceph Nano service.

# %%
spark.read.csv("s3a://bd-dist/trip_report.tsv",sep="\t").write.csv(f"s3a://{s3_bucket_name}/trip_report.tsv",sep="\t",mode="overwrite")
# Out:
# E0804 15:55:04.926597 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:55:04.938004 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-63-7020c3322d25>", line 1, in <module>
#     spark.read.csv("s3a://bd-dist/trip_report.tsv",sep="\t").write.csv(f"s3a://{s3_bucket_name}/trip_report.tsv",sep="\t",mode="overwrite")
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/session.py", line 734, in read
#     return DataFrameReader(self._wrapped)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/readwriter.py", line 70, in __init__
#     self._jreader = spark._ssql_ctx.read()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1255, in __call__
#     answer = self.gateway_client.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 983, in send_command
#     connection = self._get_connection()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 931, in _get_connection
#     connection = self._create_connection()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 937, in _create_connection
#     connection.start()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1079, in start
#     raise Py4JNetworkError(msg, e)
# py4j.protocol.Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:46581)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'Py4JNetworkError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:55:04.939778 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-63-7020c3322d25>", line 1, in <module>
#     spark.read.csv("s3a://bd-dist/trip_report.tsv",sep="\t").write.csv(f"s3a://{s3_bucket_name}/trip_report.tsv",sep="\t",mode="overwrite")
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/session.py", line 734, in read
#     return DataFrameReader(self._wrapped)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/readwriter.py", line 70, in __init__
#     self._jreader = spark._ssql_ctx.read()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1255, in __call__
#     answer = self.gateway_client.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 983, in send_command
#     connection = self._get_connection()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 931, in _get_connection
#     connection = self._create_connection()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 937, in _create_connection
#     connection.start()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1079, in start
#     raise Py4JNetworkError(msg, e)
# py4j.protocol.Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:46581)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'Py4JNetworkError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in _get_connection(self)
#     928         try:
# --> 929             connection = self.deque.pop()
#     930         except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in start(self)
#    1066         try:
# -> 1067             self.socket.connect((self.address, self.port))
#    1068             self.stream = self.socket.makefile("rb")
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# <ipython-input-63-7020c3322d25> in <module>
# ----> 1 spark.read.csv("s3a://bd-dist/trip_report.tsv",sep="\t").write.csv(f"s3a://{s3_bucket_name}/trip_report.tsv",sep="\t",mode="overwrite")
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/session.py in read(self)
#     732         :return: :class:`DataFrameReader`
#     733         """
# --> 734         return DataFrameReader(self._wrapped)
#     735
#     736     @property
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/readwriter.py in __init__(self, spark)
#      68
#      69     def __init__(self, spark):
# ---> 70         self._jreader = spark._ssql_ctx.read()
#      71         self._spark = spark
#      72
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     981          if `binary` is `True`.
#     982         """
# --> 983         connection = self._get_connection()
#     984         try:
#     985             response = connection.send_command(command)
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in _get_connection(self)
#     929             connection = self.deque.pop()
#     930         except IndexError:
# --> 931             connection = self._create_connection()
#     932         return connection
#     933
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in _create_connection(self)
#     935         connection = GatewayConnection(
#     936             self.gateway_parameters, self.gateway_property)
# --> 937         connection.start()
#     938         return connection
#     939
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in start(self)
#    1077                 "server ({0}:{1})".format(self.address, self.port)
#    1078             logger.exception(msg)
# -> 1079             raise Py4JNetworkError(msg, e)
#    1080
#    1081     def _authenticate_connection(self):
#
# Py4JNetworkError: An error occurred while trying to connect to the Java server (127.0.0.1:46581)

# %% [markdown]
# Extract all JSON files from a bucket prefix (pseudo directory) in Amazon S3 and write them back out to a bucket in our Ceph nano service with the same bucket prefix.

# %%
spark.read.option("multiline", True).option("mode", "PERMISSIVE").json("s3a://bd-dist/kube-metrics").repartition(76).write.option("compression", "bzip2").mode("overwrite").json(f"s3a://{s3_bucket_name}/kube-metrics")
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('127.0.0.1', 58706)
# E0804 15:54:31.097792 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.103325 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# Traceback (most recent call last):
#   File "/opt/rh/rh-python36/root/usr/lib64/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/opt/rh/rh-python36/root/usr/lib64/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/opt/rh/rh-python36/root/usr/lib64/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/opt/rh/rh-python36/root/usr/lib64/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/accumulators.py", line 265, in handle
#     poll(accum_updates)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/accumulators.py", line 238, in poll
#     if func():
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/accumulators.py", line 242, in accum_updates
#     num_updates = read_int(self.rfile)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/serializers.py", line 692, in read_int
#     raise EOFError
# E0804 15:54:31.106595 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# EOFError
# ----------------------------------------
# E0804 15:54:31.108496 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.109903 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.111729 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.113019 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.115836 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.117076 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.118815 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.120072 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.121760 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.122840 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.123949 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.125459 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.126693 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.128365 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.131465 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.133007 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.134091 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.135575 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.137271 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.138806 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.139921 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.141083 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.142534 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.143655 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.145771 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.147323 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
# ...
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.151730 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.152879 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.153982 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.155942 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.157096 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.159667 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.160705 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.162584 139708490286912 java_gateway.py:1078] An error occurred while trying to connect to the Java server (127.0.0.1:46581)
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 929, in _get_connection
#     connection = self.deque.pop()
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1067, in start
#     self.socket.connect((self.address, self.port))
# ConnectionRefusedError: [Errno 111] Connection refused
# E0804 15:54:31.097117 139708490286912 java_gateway.py:1003] Exception while sending command.
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1159, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py", line 1164, in send_command
#     "Error while receiving", e, proto.ERROR_ON_RECEIVE)
# py4j.protocol.Py4JNetworkError: Error while receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-59-2ca122efc480> in <module>
# ----> 1 spark.read.option("multiline", True).option("mode", "PERMISSIVE").json("s3a://bd-dist/kube-metrics").repartition(76).write.option("compression", "bzip2").mode("overwrite").json(f"s3a://{s3_bucket_name}/kube-metrics")
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/readwriter.py in json(self, path, mode, compression, dateFormat, timestampFormat)
#     775         self._set_opts(
#     776             compression=compression, dateFormat=dateFormat, timestampFormat=timestampFormat)
# --> 777         self._jwrite.json(path)
#     778
#     779     @since(1.4)
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /opt/app-root/lib/python3.6/site-packages/pyspark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     334             raise Py4JError(
#     335                 "An error occurred while calling {0}{1}{2}".
# --> 336                 format(target_id, ".", name))
#     337     else:
#     338         type = answer[1]
#
# Py4JError: An error occurred while calling o210.json

# %% [markdown]
# # Working with SparkSQL

# %% [markdown]
# Load Prometheus data set from Ceph Nano into a data frame.

# %%
jsonFile = spark.read.json(f"s3a://{s3_bucket_name}/kube-metrics")

# %% [markdown]
# __Import statistics libraries__

# %%
import pandas as pd
import json
import numpy as np
import seaborn as sns
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# __Display schema of files__

# %%
print('Display schema:')
jsonFile.printSchema()

# %% [markdown]
# # Save the model, tokenizer and feature dimension and store them in Ceph

# %%
model.save("./model")

import pickle

with open('./tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

feature_dimension = X_highlights_train.shape[1]
with open('./feature_dimension.pickle', 'wb') as handle:
    pickle.dump(feature_dimension, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import boto3
s3 = boto3.resource('s3')

#Create S3 session for writing manifest file
session = boto3.Session(
    aws_access_key_id = s3_access_key,
    aws_secret_access_key = s3_secret_key
)

s3 = session.resource('s3', endpoint_url=s3_endpoint_url, verify=False)

# Upload the model to S3
s3.meta.client.upload_file('./model', s3_bucket_name, 'models/trip_report_model')

# Upload the tokenizer to S3
s3.meta.client.upload_file('./tokenizer.pickle', s3_bucket_name, 'models/trip_report_tokenizer.pickle')

# Upload the feature dimension to S3
s3.meta.client.upload_file('./feature_dimension.pickle', s3_bucket_name, 'models/trip_report_feature_dimension.pickle')

# %% [markdown]
# The model has been saved to s3 as binary objects and can be viewed
